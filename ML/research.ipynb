# %% [markdown]
# ### EDA on products datasets from kaggle

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /var/folders/cv/57_q_p5n4cncc53s74r1mjy80000gn/T/ipykernel_79811/137877977.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
amz_categories = pd.read_csv('amazon_categories.csv')

amz_categories = pd.DataFrame(amz_categories)

amz_categories
# Out:
#       id                                    category_name
# 0      1                         Beading & Jewelry Making
# 1      2                                Fabric Decorating
# 2      3                      Knitting & Crochet Supplies
# 3      4                             Printmaking Supplies
# 4      5                 Scrapbooking & Stamping Supplies
# ..   ...                                              ...
# 243  262  Xbox Series X & S Consoles, Games & Accessories
# 244  263                           PC Games & Accessories
# 245  264                     Baby Girls' Clothing & Shoes
# 246  265                            Boys' School Uniforms
# 247  270                                     Toys & Games
#
# [248 rows x 2 columns]

# %%
amz_products = pd.read_csv('amazon_products.csv')

amz_products = pd.DataFrame(amz_products)

amz_products
# Out:
#                asin                                              title  \
# 0        B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1        B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2        B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3        B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4        B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...             ...                                                ...
# 1426332  B00R3LIKCO  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  B098BQ7ZQ3  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  B07X1MVNT1  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  B08XLBG8V9                          Ax2002 Aviator Sunglasses
# 1426336  B07GH67QC8  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                     imgUrl  \
# ...

# %%
amz_products.describe()
# Out:
#               stars       reviews         price     listPrice   category_id  \
# count  1.426337e+06  1.426337e+06  1.426337e+06  1.426337e+06  1.426337e+06
# mean   3.999512e+00  1.807508e+02  4.337540e+01  1.244916e+01  1.237409e+02
# std    1.344292e+00  1.761453e+03  1.302893e+02  4.611198e+01  7.311273e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# 25%    4.100000e+00  0.000000e+00  1.199000e+01  0.000000e+00  6.500000e+01
# 50%    4.400000e+00  0.000000e+00  1.995000e+01  0.000000e+00  1.200000e+02
# 75%    4.600000e+00  0.000000e+00  3.599000e+01  0.000000e+00  1.760000e+02
# max    5.000000e+00  3.465630e+05  1.973181e+04  9.999900e+02  2.700000e+02
#
#        boughtInLastMonth
# count       1.426337e+06
# mean        1.419823e+02
# std         8.362720e+02
# min         0.000000e+00
# 25%         0.000000e+00
# 50%         0.000000e+00
# 75%         5.000000e+01
# max         1.000000e+05

# %%
amz_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426337 entries, 0 to 1426336
# Data columns (total 11 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   asin               1426337 non-null  object
#  1   title              1426336 non-null  object
#  2   imgUrl             1426337 non-null  object
#  3   productURL         1426337 non-null  object
#  4   stars              1426337 non-null  float64
#  5   reviews            1426337 non-null  int64
#  6   price              1426337 non-null  float64
#  7   listPrice          1426337 non-null  float64
#  8   category_id        1426337 non-null  int64
#  9   isBestSeller       1426337 non-null  bool
#  10  boughtInLastMonth  1426337 non-null  int64
# dtypes: bool(1), float64(3), int64(3), object(4)
# memory usage: 110.2+ MB

# %%
amz = pd.merge(amz_categories,amz_products, left_on='id', right_on='category_id')

amz.head(10)
# Out:
#    id             category_name        asin  \
# 0   1  Beading & Jewelry Making  B08YNTXFJG
# 1   1  Beading & Jewelry Making  B08DXSF5PZ
# 2   1  Beading & Jewelry Making  B096JGXQN5
# 3   1  Beading & Jewelry Making  B0BZXW1ZGS
# 4   1  Beading & Jewelry Making  B0BR8B472F
# 5   1  Beading & Jewelry Making  B096HTDZR5
# 6   1  Beading & Jewelry Making  B07SVCV8VB
# 7   1  Beading & Jewelry Making  B0B4689HLD
# 8   1  Beading & Jewelry Making  B09YRKCH71
# 9   1  Beading & Jewelry Making  B08ZXBT6RY
#
#                                                title  \
# 0  Duufin 120 Pieces Acrylic Keychain Blanks Set ...
# 1  DIY Tray Silicone Resin Mold, Oval Epoxy Resin...
# 2  GTOTd I Love Rock and Roll Pins Set(18 Pack,2....
# 3  Xuhal 100 Pack Plastic Ring Sizer Bulk Reusabl...
# 4  Large Dice Resin Molds, 2 Styles Silicone Dice...
# 5  10 Pieces 25 mm Bezel Tray Blank Bangle Bracel...
# 6  100pcs Adabele Authentic 925 Sterling Silver C...
# ...

# %%
amz = amz.drop(columns=['category_id','asin','imgUrl','productURL'])
amz.head(10)
# Out:
#    id             category_name  \
# 0   1  Beading & Jewelry Making
# 1   1  Beading & Jewelry Making
# 2   1  Beading & Jewelry Making
# 3   1  Beading & Jewelry Making
# 4   1  Beading & Jewelry Making
# 5   1  Beading & Jewelry Making
# 6   1  Beading & Jewelry Making
# 7   1  Beading & Jewelry Making
# 8   1  Beading & Jewelry Making
# 9   1  Beading & Jewelry Making
#
#                                                title  stars  reviews  price  \
# 0  Duufin 120 Pieces Acrylic Keychain Blanks Set ...    4.7      510   9.99
# 1  DIY Tray Silicone Resin Mold, Oval Epoxy Resin...    4.6      584   8.99
# 2  GTOTd I Love Rock and Roll Pins Set(18 Pack,2....    4.5      245  12.79
# 3  Xuhal 100 Pack Plastic Ring Sizer Bulk Reusabl...    5.0        1  16.99
# 4  Large Dice Resin Molds, 2 Styles Silicone Dice...    4.4       10  15.99
# 5  10 Pieces 25 mm Bezel Tray Blank Bangle Bracel...    4.4      130  14.99
# ...

# %%
flipkart = pd.read_csv('flipkart_com-ecommerce_sample.csv')
flipkart = pd.DataFrame(flipkart)

flipkart
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
flipkart = flipkart.drop(columns=['crawl_timestamp','product_url','pid','image'])

flipkart.head(10)
# Out:
#                             uniq_id  \
# 0  c2d766ca982eca8304150849735ffef9
# 1  7f7036a6d550aaa89d34c77bd39a5e48
# 2  f449ec65dcbc041b6ae5e6a32717d01b
# 3  0973b37acd0c664e3de26e97e5571454
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7
# 5  c2a17313954882c1dba461863e98adf2
# 6  ce5a6818f7707e2cb61fdcdbba61f5ad
# 7  8542703ca9e6ebdf6d742638dfb1f2ca
# 8  29c8d290caa451f97b1c32df64477a2c
# 9  4044c0ac52c1ee4b28777417651faf42
#
#                                         product_name  \
# 0                Alisha Solid Women's Cycling Shorts
# 1                FabHomeDecor Fabric Double Sofa Bed
# 2                                         AW Bellies
# 3                Alisha Solid Women's Cycling Shorts
# 4              Sicons All Purpose Arnica Dog Shampoo
# 5  Eternal Gandhi Super Series Crystal Paper Weig...
# 6                Alisha Solid Women's Cycling Shorts
# 7                FabHomeDecor Fabric Double Sofa Bed
# 8  dilli bazaaar Bellies, Corporate Casuals, Casuals
# ...

# %%
flipkart = flipkart.drop(columns=['product_specifications','overall_rating','is_FK_Advantage_product'])
flipkart.head(10)
# Out:
#                             uniq_id  \
# 0  c2d766ca982eca8304150849735ffef9
# 1  7f7036a6d550aaa89d34c77bd39a5e48
# 2  f449ec65dcbc041b6ae5e6a32717d01b
# 3  0973b37acd0c664e3de26e97e5571454
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7
# 5  c2a17313954882c1dba461863e98adf2
# 6  ce5a6818f7707e2cb61fdcdbba61f5ad
# 7  8542703ca9e6ebdf6d742638dfb1f2ca
# 8  29c8d290caa451f97b1c32df64477a2c
# 9  4044c0ac52c1ee4b28777417651faf42
#
#                                         product_name  \
# 0                Alisha Solid Women's Cycling Shorts
# 1                FabHomeDecor Fabric Double Sofa Bed
# 2                                         AW Bellies
# 3                Alisha Solid Women's Cycling Shorts
# 4              Sicons All Purpose Arnica Dog Shampoo
# 5  Eternal Gandhi Super Series Crystal Paper Weig...
# 6                Alisha Solid Women's Cycling Shorts
# 7                FabHomeDecor Fabric Double Sofa Bed
# 8  dilli bazaaar Bellies, Corporate Casuals, Casuals
# ...

# %%
fashion = pd.read_csv('fashion_products.csv')

fashion = pd.DataFrame(fashion)


fashion
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 1    4.026416   Black    L
# 2    3.337938  Yellow   XL
# ...
